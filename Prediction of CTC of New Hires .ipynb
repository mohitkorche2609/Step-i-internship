# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Loading datasets

# %%
train_data=pd.read_excel("C:\\Users\\tusha\\Downloads\\Data_file.xlsx",header=2)
test_data=pd.read_excel("C:\\Users\\tusha\\Downloads\\Test_data_file.xlsx")

# %% [markdown]
# # Processing Datasets

# %%
train_data.head()
# Out:
#    S.No. College       Role  City type  Previous CTC  Previous job changes  \
# 0      1  Tier 1    Manager  Non-Metro         55523                     3
# 1      2  Tier 2  Executive      Metro         57081                     1
# 2      3  Tier 2  Executive      Metro         60347                     2
# 3      4  Tier 3  Executive      Metro         49010                     2
# 4      5  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
del train_data["S.No."]

# %%
train_data.head()
# Out:
#   College       Role  City type  Previous CTC  Previous job changes  \
# 0  Tier 1    Manager  Non-Metro         55523                     3
# 1  Tier 2  Executive      Metro         57081                     1
# 2  Tier 2  Executive      Metro         60347                     2
# 3  Tier 3  Executive      Metro         49010                     2
# 4  Tier 3  Executive      Metro         57879                     4
#
#    Graduation marks  Exp (Months)           CTC
# 0                66            19  71406.576531
# 1                84            18  68005.870631
# 2                52            28  76764.020277
# 3                81            33  82092.386880
# 4                74            32  73878.097729

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   College               1338 non-null   object
#  1   Role                  1338 non-null   object
#  2   City type             1338 non-null   object
#  3   Previous CTC          1338 non-null   int64
#  4   Previous job changes  1338 non-null   int64
#  5   Graduation marks      1338 non-null   int64
#  6   Exp (Months)          1338 non-null   int64
#  7   CTC                   1338 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 83.8+ KB

# %%
train_data.describe()
# Out:
#        Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# count   1338.000000           1338.000000       1338.000000   1338.000000
# mean   55581.762332              2.525411         59.890882     39.207025
# std     6685.600553              1.123502         14.894696     14.049960
# min    36990.000000              1.000000         35.000000     18.000000
# 25%    50547.000000              2.000000         47.000000     27.000000
# 50%    55293.500000              3.000000         60.000000     39.000000
# 75%    60150.500000              4.000000         73.000000     51.000000
# max    77911.000000              4.000000         85.000000     64.000000
#
#                  CTC
# count    1338.000000
# mean    75459.338993
# std     12551.280263
# min     53020.319026
# 25%     66905.070033
# 50%     73112.640487
# 75%     80747.178420
# max    123416.994271

# %%
test_data.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  ...  \
# 0           0         55523                     3                66  ...
# 1           1         57081                     1                84  ...
# 2           1         60347                     2                52  ...
# 3           1         49010                     2                81  ...
# 4           1         57879                     4                74  ...
#
#    Unnamed: 14   Unnamed: 15  Unnamed: 16  Unnamed: 17   Unnamed: 18  \
# ...

# %% [markdown]
# # Visualisation of Data

# %% [markdown]
# college_data=train_data.groupby("College").sum()

# %%
college_data.head()
# Out:
#          Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# College
# Tier 1       35670161                  1667             39026         25546
# Tier 2       21155512                   925             21894         14174
# Tier 3       17542725                   787             19214         12739
#
#                   CTC
# College
# Tier 1   5.035953e+07
# Tier 2   2.715483e+07
# Tier 3   2.345024e+07

# %%
plt.boxplot(college_data)
plt.title("College Tier vs CTC")
plt.xlabel("Tier")
plt.ylabel("CTC")

plt.show()

# %%
x=train_data["Graduation marks"]
y=train_data["CTC"]
plt.bar(x,y)
plt.title("Graduation Marks vs CTC")
plt.xlabel("Marks")
plt.ylabel("CTC")
plt.show()

# %%
x=train_data["Exp (Months)"]
y=train_data["CTC"]
plt.bar(x,y)
plt.title("Experience vs CTC")
plt.xlabel("Experience(in Months)")
plt.ylabel("CTC")
plt.show()

# %%
train_data=pd.get_dummies(train_data,drop_first=True)
train_data.head()
# Out:
#    Previous CTC  Previous job changes  Graduation marks  Exp (Months)  \
# 0         55523                     3                66            19
# 1         57081                     1                84            18
# 2         60347                     2                52            28
# 3         49010                     2                81            33
# 4         57879                     4                74            32
#
#             CTC  College_Tier 2  College_Tier 3  Role_Manager  \
# 0  71406.576531               0               0             1
# 1  68005.870631               1               0             0
# 2  76764.020277               1               0             0
# 3  82092.386880               0               1             0
# 4  73878.097729               0               1             0
#
#    City type_Non-Metro
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
test_data=pd.get_dummies(test_data,drop_first=True)
test_data.head()
# Out:
#    College_T1  College_T2  Role_Manager  City_Metro  previous CTC  \
# 0           1           0             1           0         55523
# 1           0           1             0           1         57081
# 2           0           1             0           1         60347
# 3           0           0             0           1         49010
# 4           0           0             0           1         57879
#
#    previous job changes  Graduation marks  Exp    Actual CTC  Predicted CTC  \
# 0                     3                66   19  71406.576531            NaN
# 1                     1                84   18  68005.870631            NaN
# 2                     2                52   28  76764.020277            NaN
# 3                     2                81   33  82092.386880            NaN
# 4                     4                74   32  73878.097729            NaN
#
#    ...   Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  \
# ...

# %%
pip install -U scikit-learn matplotlib
# Out:
# ...
#
#   Using cached scikit_learn-1.1.3-cp311-cp311-win_amd64.whl (7.5 MB)
# ...
#      ---------------------------------------- 39.9/39.9 MB 5.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 298.0/298.0 kB 9.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()

# %%
x=train_data.drop("CTC",axis=1)
y=train_data["CTC"]

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x)
print("Prediction:",y_pred)
# Out:
# Prediction: [86123.93814045 65789.54652723 69941.69030152 ... 64046.07444784
#  66223.22234281 90794.94065705]

# %% [markdown]
# # Calculation of Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error

# %%
print("Mean Squared Error is:",mean_squared_error(y,y_pred))
# Out:
# Mean Squared Error is: 61677937.04530962

# %%
predicted=pd.concat([test_data,pd.DataFrame(y_pred,columns=["Predicted CTC"])],axis=1)

# %%
predicted=predicted[["College_Tier 2","College_Tier 3","City type_Non-Metro","Graduation marks","Role_Manager","Actual CTC","Predicted CTC"]]

# %%
print("Prediction of CTC/Salary of new hires:")
predicted.head()
# Out:
# Prediction of CTC/Salary of new hires:
#    College_Tier 2  College_Tier 3  City type_Non-Metro  Graduation marks  \
# 0               0               0                    1                66
# 1               1               0                    0                84
# 2               1               0                    0                52
# 3               0               1                    0                81
# 4               0               1                    0                74
#
#    Role_Manager  Role_Manager    Actual CTC  Predicted CTC  Predicted CTC
# 0             1             1  71406.576531            NaN   86123.938140
# 1             0             0  68005.870631            NaN   65789.546527
# 2             0             0  76764.020277            NaN   69941.690302
# 3             0             0  82092.386880            NaN   66843.038384
# 4             0             0  73878.097729            NaN   70556.761762
